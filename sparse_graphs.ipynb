# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

# %%
n = 10 # number of nodes
r = 1 # rank
p = 0.1 # number of edges

A = np.random.random([n,r])

adjacency_matrixA = np.zeros([n, n])
adjacency_matrixA[np.dot(A, A.T) < p] = 1

# %%
G = nx.from_numpy_matrix(adjacency_matrixA, create_using=nx.MultiDiGraph())

fig=plt.figure(figsize=(18, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(1,2,1)
nx.draw_circular(G)
plt.axis('equal')

plt.subplot(1,2,2)
plt.imshow(adjacency_matrixA)

# %%
n = 10 # number of nodes
r = 1 # rank
p = 0.1 # number of edges

B = np.random.random([n,r])

adjacency_matrixB = np.zeros([n, n])
adjacency_matrixB[np.dot(B, B.T) < p] = 1

# %%
G = nx.from_numpy_matrix(adjacency_matrixB, create_using=nx.MultiDiGraph())

fig=plt.figure(figsize=(18, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(1,2,1)
nx.draw_circular(G)
plt.axis('equal')

plt.subplot(1,2,2)
plt.imshow(adjacency_matrixB)

# %%
C = np.dot(A, B.T)

adjacency_matrix = np.zeros([n, n])
adjacency_matrix[C < p] = 1

G = nx.from_numpy_matrix(adjacency_matrix, create_using=nx.MultiDiGraph())

fig=plt.figure(figsize=(18, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(1,2,1)
nx.draw_circular(G)
plt.axis('equal')

plt.subplot(1,2,2)
plt.imshow(adjacency_matrix)
